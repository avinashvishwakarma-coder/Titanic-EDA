# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('taitanic data.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#keeping relevant colums

# %%
df.drop(columns=['PassengerId','Name','Ticket','Cabin'],inplace=True)

# %%
df.sample(7)
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch      Fare Embarked
# 215         1       1  female  31.0      1      0  113.2750        C
# 402         0       3  female  21.0      1      0    9.8250        S
# 460         1       1    male  48.0      0      0   26.5500        S
# 851         0       3    male  74.0      0      0    7.7750        S
# 81          1       3    male  29.0      0      0    9.5000        S
# 542         0       3  female  11.0      4      2   31.2750        S
# 420         0       3    male   NaN      0      0    7.8958        C

# %%
#lets know our data

# %%
df.shape
# Out:
# (891, 8)

# %%
df.isna().sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Fare          0
# Embarked      2
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Sex       891 non-null    object
#  3   Age       714 non-null    float64
#  4   SibSp     891 non-null    int64
#  5   Parch     891 non-null    int64
#  6   Fare      891 non-null    float64
#  7   Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(2)
# memory usage: 55.8+ KB

# %%
df.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.duplicated().sum()
# Out:
# np.int64(111)

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (780, 8)

# %%
df.isna().sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age         104
# SibSp         0
# Parch         0
# Fare          0
# Embarked      2
# dtype: int64

# %%
df.corr(numeric_only=True)
# Out:
#           Survived    Pclass       Age     SibSp     Parch      Fare
# Survived  1.000000 -0.336244 -0.084985 -0.037597  0.069669  0.246669
# Pclass   -0.336244  1.000000 -0.366477  0.086788  0.038975 -0.552440
# Age      -0.084985 -0.366477  1.000000 -0.314239 -0.193819  0.093877
# SibSp    -0.037597  0.086788 -0.314239  1.000000  0.380596  0.134127
# Parch     0.069669  0.038975 -0.193819  0.380596  1.000000  0.191055
# Fare      0.246669 -0.552440  0.093877  0.134127  0.191055  1.000000

# %%
#univariant EDA

# %%
#count plot

# %%
df.sample()
# Out:
#      Survived  Pclass     Sex  Age  SibSp  Parch   Fare Embarked
# 888         0       3  female  NaN      1      2  23.45        S

# %%
sns.countplot(df['Sex'])
# Out:
# <Axes: xlabel='count', ylabel='Sex'>

# %%
#pie chart

# %%
df['Embarked'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
#numerical univariant EDA

# %%
df.sample()
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 215         1       1  female  31.0      1      0  113.275        C

# %%
plt.hist(df['Survived'],bins=2)
plt.grid()
plt.show()

# %%
sns.displot(df['Age'])

# %%
sns.boxplot(df['Age'])
# Out:
# <Axes: ylabel='Age'>

# %%
df["Age"].describe()
# Out:
# count    676.000000
# mean      29.812751
# std       14.727098
# min        0.420000
# 25%       20.000000
# 50%       28.000000
# 75%       39.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
#bivariant 
#scatterplot

# %%
df.sample()
# Out:
#      Survived  Pclass   Sex   Age  SibSp  Parch     Fare Embarked
# 509         1       3  male  26.0      0      0  56.4958        S

# %%
sns.scatterplot(x=df['Age'],y=df['Fare'],hue=df['Survived'],style=df['Sex'],size=df['Pclass'])
# Out:
# <Axes: xlabel='Age', ylabel='Fare'>

# %%
sns.barplot(x=df['Pclass'],y=df['Age'],hue=df['Survived'])
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %%
sns.boxplot(x=df['Sex'],y=df['Age'],hue=df['Survived'],)
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
sns.distplot(df[df['Survived']==0]['Age'],hist=False)
sns.distplot(df[df['Survived']==1]['Age'],hist=False)
# Out:
# C:\Users\Avinash\AppData\Local\Temp\ipykernel_12024\908429420.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df['Survived']==0]['Age'],hist=False)
# C:\Users\Avinash\AppData\Local\Temp\ipykernel_12024\908429420.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
sns.heatmap(pd.crosstab(df['Pclass'],df['Survived']))
# Out:
# <Axes: xlabel='Survived', ylabel='Pclass'>

# %%
sns.clustermap(pd.crosstab(df['Pclass'],df['Survived']))

# %%
sns.pairplot(df,hue='Sex')

# %%
#not much useful
